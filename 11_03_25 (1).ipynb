# %%
import google.generativeai as genai
from google.colab import userdata

GOOGLE_API_KEY = userdata.get('google')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
import pathlib

import textwrap

from IPython.display import display, Markdown

def to_markdown(text):

  text = text.replace('•', '  *')

  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import PIL.Image
img = PIL.Image.open('image1.jpg')
img
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(["Write a short, engaging blog post based on this picture.It should include a description of the meal in the photo and talk about my journey meal prepping.",img],
stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# > ## My Meal Prep Journey: From Chaos to Calm (and Delicious!)
# >
# > Let's be honest, weekday dinners used to be a stressful scramble.  Between work, errands, and everything else, finding the time (and energy!) to cook a healthy, satisfying meal felt impossible.  Enter meal prepping!
# >
# > The picture shows the delicious results of my latest meal prep session: two containers brimming with flavorful teriyaki chicken and broccoli, vibrant red and orange carrots, and a fluffy bed of white rice. It’s a balanced and satisfying meal, perfect for a busy weeknight.  Each serving is portioned perfectly, ensuring I stick to my healthy eating goals. No more late-night takeout temptations!
# >
# > My journey with meal prepping hasn't been without its bumps.  Initially, I tried to prep too much too soon.  My kitchen looked like a disaster zone, and honestly, some of the food ended up going to waste.  But I learned!  I now focus on smaller, manageable batches. I pick recipes that are simple, utilize similar ingredients, and most importantly, ones I actually *enjoy* eating.
# >
# > The key to my success? Planning is everything.  I spend about an hour or two on the weekend prepping all my ingredients and cooking the main components.  Then, during the week, assembling the meals is a breeze—a quick five-minute process.
# >
# > Meal prepping isn’t about slavishly following strict diets. It's about taking control of your eating habits and making healthy, delicious choices easier.  It's about making a conscious decision to prioritize your well-being and enjoying the delicious fruits (and vegetables!) of your labor.  This teriyaki chicken and veggie bowl is just one example of how easy, and how rewarding, this journey can be.  What are your favourite meal prep recipes? Let me know in the comments!

# %%
response = model.generate_content(["Generate an accurate caption for this image.", img])
print(response.text)
# Out:
# Here are a few caption options for the image:
#
# **Option 1 (Simple & Descriptive):**
#
# > Healthy and delicious meal prep!  Chicken and broccoli with rice.
#
# **Option 2 (More Engaging):**
#
# > Lunch goals!  These chicken and veggie bowls are packed with flavor and ready to go.  #mealprep #healthyfood #lunchideas
#
# **Option 3 (Focus on Convenience):**
#
# > Easy weeknight dinners just got easier!  Prepped these yummy chicken and rice bowls for a stress-free week. #mealprepsunday #healthylifestyle #easyrecipes
#
# **Option 4 (A Bit More Playful):**
#
# > My kind of takeout... except I made it myself!  #mealprep #healthymeals #chickenandbroccoli
#
#
# Choose the caption that best suits your intended audience and platform.

# %%
from PIL import Image
image_path = "girl.jpg"
image = Image.open(image_path)
response = model.generate_content(["Describe this image in detail.", image])
print(response.text)
# Out:
# Here's a description of the image:
#
# Close-up view of a woman with medium-brown, curly hair that falls to her shoulders. She's smiling and pointing to her left with her index finger. She appears to be of South Asian descent.
#
#
# She is wearing a teal-colored, three-quarter-sleeved tunic or kurta. The tunic has a subtle, all-over print of small, gold-colored floral or paisley-like designs. It has a simple, slightly open neckline. Her arms are crossed, with one arm bent at the elbow and her pointing hand extended.
#
#
# The background is a plain, bright white, which keeps the focus entirely on the woman. The lighting is soft and even, minimizing harsh shadows. The overall impression is one of a friendly, approachable woman gesturing towards something off-camera.

# %%
response = model.generate_content(["What emotions can you detect in this image? ", image])
print(response.text)
# Out:
# The woman in the image appears to be expressing confidence and approachability.  Her smile is warm, and the gesture of pointing suggests she is inviting interaction or offering information.  There's also a hint of playfulness in her expression.

# %%
image_path = "quote.jpg"
image = Image.open(image_path)
response = model.generate_content(["Extract and read the text from this image.", image])
print(response.text)
# Out:
# Here's the text from the image:
#
# FAILURE is not the
# opposite of success
# it's PART OF
# SUCCESS
