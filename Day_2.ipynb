# %% [markdown]
# <a href="https://colab.research.google.com/github/Esha354-gif/ad-nlp/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Declare variables of different data types
int_var = 10            # Integer
float_var = 3.14        # Float
str_var = "Hello, World!" # String
bool_var = True         # Boolean

# Print each variable and its type
print(f"Integer Variable: {int_var}, Type: {type(int_var)}")
print(f"Float Variable: {float_var}, Type: {type(float_var)}")
print(f"String Variable: '{str_var}', Type: {type(str_var)}")
print(f"Boolean Variable: {bool_var}, Type: {type(bool_var)}")
# Out:
# Integer Variable: 10, Type: <class 'int'>
# Float Variable: 3.14, Type: <class 'float'>
# String Variable: 'Hello, World!', Type: <class 'str'>
# Boolean Variable: True, Type: <class 'bool'>
